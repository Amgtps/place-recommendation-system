# %%
# !pip install google
# Out:
# ...
#      -------------------------------------- 45.3/45.3 kB 745.1 kB/s eta 0:00:00
# ...

# %%
import pandas as pd 
import numpy as np 

from googlesearch import search

# %%
pd.read_csv('main_cleaned.csv').dropna(subset = ['place'])
# Out:
#        state_name_x       city_name                      place  \
# 0             Bihar     Muzaffarpur            Litchi Gardens
# 1             Bihar     Muzaffarpur        Garib Sthan Mandir
# 2             Bihar     Muzaffarpur          Jubba Sahni Park
# 3             Bihar     Muzaffarpur    Khudiram Bose Memorial
# 4             Bihar     Muzaffarpur   Ramchandra Shahi Museum
# ...             ...             ...                        ...
# 6043  Uttar Pradesh      Kushinagar                        NaN
# 6044  Uttar Pradesh  Garhmukteshwar                        NaN
# 6045  Uttar Pradesh        Pilibhit                        NaN
# 6046    West Bengal        Bagdogra                        NaN
# 6047    West Bengal         Asansol                        NaN
#
#                                             description  \
# 0      Muzaffarpur is one of the leaders in the prod...
# 1      One of the centres of attraction of Muzaffarp...
# ...
